# %%
#Given: Three positive integers k, m, and n, representing a population containing k+m+n organisms:
#k individuals are homozygous dominant for a factor, m are heterozygous, and n are homozygous recessive.

#Return: The probability that two randomly selected mating organisms will produce an individual possessing a dominant allele
#(and thus displaying the dominant phenotype).
#Assume that any two organisms can mate.

# %%
k = 22 #homozygous dominant AA
k_list = ["A","A"]
m = 15 #heterozygous  Aa
m_list = ["A","a"]
n = 16 #homozygous recessive aa
n_list = ["a","a"]
total = k + m + n
k_prob = k / total #probabilty of k (AA)
m_prob = m / total #probability of m (Aa)
n_prob = n/ total #probability of n (aa)


#k first
kk = (k_prob * ((k-1)/(total-1)))
km = (k_prob * (m / (total-1)))
kn = k_prob * (n / (total-1))

#m first
mm = (m_prob * ((m-1) / (total - 1))) * (3/4)
mk = (m_prob * (k / (total -1))) * 1
mn = (m_prob * (n / (total -1))) * (1/2)

#n first

nn = (n_prob * ((n-1) / (total - 1))) * 0
nk = (n_prob * (k / (total - 1))) * 1
nm = (n_prob * (m / (total - 1))) * (1/2)


total_suitable = kk + km + kn + mm + mk + mn + nn + nk + nm

print(total_suitable)
print("")





print("k with m")
for k_allele in k_list:
    for m_allele in m_list:
        results = k_allele + m_allele
        print(results)
print("")

print("k with k")
for k_allele in k_list:
    for k1_allele in k_list:
        results = k1_allele + k_allele
        print(results)
print("")

print("k with n")
for k_allele in k_list:
    for n_allele in n_list:
        results = k_allele + n_allele
        print(results)
print("")

print("m with m")
for m_allele in m_list:
    for m1_allele in m_list:
        results = m1_allele + m_allele
        print(results)
print("")

print("n with n")
for n_allele in n_list:
    for n1_allele in n_list:
        results = n1_allele + n_allele
        print(results)

print("m with n")
for m_allele in m_list:
    for n_allele in n_list:
        results = m_allele + n_allele
        print(results)
# Out:
# 0.8067851959361393
#
# k with m
# AA
# Aa
# AA
# Aa
#
# k with k
# AA
# AA
# AA
# AA
#
# k with n
# Aa
# Aa
# Aa
# Aa
#
# m with m
# AA
# aA
# Aa
# aa
#
# n with n
# aa
# aa
# aa
# aa
# m with n
# Aa
# Aa
# aa
# aa
